# %%
import xgboost as xgb
from sklearn.model_selection import ShuffleSplit
import pandas as pd
import numpy as np
# Out:
# /home/rizkiduwinanto/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv('../data/veterans_lung_cancer.csv')
df.describe()
# Out:
# /home/rizkiduwinanto/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#        Survival_label_lower_bound  Survival_label_upper_bound  Age_in_years  \
# count                  137.000000                       137.0    137.000000
# mean                   121.627737                         inf     58.306569
# std                    157.816722                         NaN     10.541628
# min                      1.000000                         1.0     34.000000
# 25%                     25.000000                        25.0     51.000000
# 50%                     80.000000                        80.0     62.000000
# 75%                    144.000000                       177.0     66.000000
# max                    999.000000                         inf     81.000000
#
#        Karnofsky_score  Months_from_Diagnosis  Celltype=adeno  Celltype=large  \
# count       137.000000             137.000000      137.000000      137.000000
# mean         58.569343               8.773723        0.197080        0.197080
# std          20.039592              10.612141        0.399253        0.399253
# min          10.000000               1.000000        0.000000        0.000000
# 25%          40.000000               3.000000        0.000000        0.000000
# 50%          60.000000               5.000000        0.000000        0.000000
# 75%          75.000000              11.000000        0.000000        0.000000
# max          99.000000              87.000000        1.000000        1.000000
#
#        Celltype=smallcell  Celltype=squamous  Prior_therapy=no  \
# count          137.000000         137.000000        137.000000
# mean             0.350365           0.255474          0.708029
# std              0.478835           0.437728          0.456337
# min              0.000000           0.000000          0.000000
# 25%              0.000000           0.000000          0.000000
# 50%              0.000000           0.000000          1.000000
# 75%              1.000000           1.000000          1.000000
# max              1.000000           1.000000          1.000000
#
#        Prior_therapy=yes  Treatment=standard  Treatment=test
# count         137.000000          137.000000      137.000000
# mean            0.291971            0.503650        0.496350
# std             0.456337            0.501821        0.501821
# min             0.000000            0.000000        0.000000
# 25%             0.000000            0.000000        0.000000
# 50%             0.000000            1.000000        0.000000
# 75%             1.000000            1.000000        1.000000
# max             1.000000            1.000000        1.000000

# %%
y_lower_bound = df['Survival_label_lower_bound']
y_upper_bound = df['Survival_label_upper_bound']
X = df.drop(['Survival_label_lower_bound', 'Survival_label_upper_bound'], axis=1)
y_lower_bound, y_upper_bound
# Out:
# (0       72.0
#  1      411.0
#  2      228.0
#  3      126.0
#  4      118.0
#         ...
#  132    133.0
#  133    111.0
#  134    231.0
#  135    378.0
#  136     49.0
#  Name: Survival_label_lower_bound, Length: 137, dtype: float64,
#  0       72.0
#  1      411.0
#  2      228.0
#  3      126.0
#  4      118.0
#         ...
#  132    133.0
#  133    111.0
#  134    231.0
#  135    378.0
#  136     49.0
#  Name: Survival_label_upper_bound, Length: 137, dtype: float64)

# %%
X
# Out:
#      Age_in_years  Karnofsky_score  Months_from_Diagnosis  Celltype=adeno  \
# 0            69.0             60.0                    7.0               0
# 1            64.0             70.0                    5.0               0
# 2            38.0             60.0                    3.0               0
# 3            63.0             60.0                    9.0               0
# 4            65.0             70.0                   11.0               0
# ..            ...              ...                    ...             ...
# 132          65.0             75.0                    1.0               0
# 133          64.0             60.0                    5.0               0
# 134          67.0             70.0                   18.0               0
# 135          65.0             80.0                    4.0               0
# 136          37.0             30.0                    3.0               0
#
#      Celltype=large  Celltype=smallcell  Celltype=squamous  Prior_therapy=no  \
# 0                 0                   0                  1                 1
# 1                 0                   0                  1                 0
# 2                 0                   0                  1                 1
# 3                 0                   0                  1                 0
# 4                 0                   0                  1                 0
# ..              ...                 ...                ...               ...
# 132               1                   0                  0                 1
# 133               1                   0                  0                 1
# 134               1                   0                  0                 0
# 135               1                   0                  0                 1
# 136               1                   0                  0                 1
#
#      Prior_therapy=yes  Treatment=standard  Treatment=test
# 0                    0                   1               0
# 1                    1                   1               0
# 2                    0                   1               0
# 3                    1                   1               0
# 4                    1                   1               0
# ..                 ...                 ...             ...
# 132                  0                   0               1
# 133                  0                   0               1
# 134                  1                   0               1
# 135                  0                   0               1
# 136                  0                   0               1
#
# [137 rows x 11 columns]

# %%
rs = ShuffleSplit(n_splits=2, test_size=.2, random_state=42)
train_index, valid_index = next(rs.split(X))
len(train_index), len(valid_index)
# Out:
# (109, 28)

# %%
dtrain = xgb.DMatrix(X.values[train_index, :])
dtrain.set_float_info('label_lower_bound', y_lower_bound[train_index])
dtrain.set_float_info('label_upper_bound', y_upper_bound[train_index])

# %%
dvalid = xgb.DMatrix(X.values[valid_index, :])
dvalid.set_float_info('label_lower_bound', y_lower_bound[valid_index])
dvalid.set_float_info('label_upper_bound', y_upper_bound[valid_index])

# %%
params = {'verbosity': 0,
          'objective': 'survival:aft',
          'eval_metric': 'aft-nloglik',
          'tree_method': 'hist',
          'learning_rate': 0.05,
          'aft_loss_distribution': 'normal',
          'aft_loss_distribution_scale': 1.20,
          'max_depth': 5,
          'lambda': 0.01,
          'alpha': 0.02}

bst = xgb.train(params, dtrain, num_boost_round=10000,
                evals=[(dtrain, 'train'), (dvalid, 'valid')],
                early_stopping_rounds=50)
# Out:
# [0]	train-aft-nloglik:12.66083	valid-aft-nloglik:12.95680
# [1]	train-aft-nloglik:11.91472	valid-aft-nloglik:12.24435
# [2]	train-aft-nloglik:11.24083	valid-aft-nloglik:11.58992
# [3]	train-aft-nloglik:10.63209	valid-aft-nloglik:11.00682
# [4]	train-aft-nloglik:10.08223	valid-aft-nloglik:10.48380
# [5]	train-aft-nloglik:9.58555	valid-aft-nloglik:10.00134
# [6]	train-aft-nloglik:9.13669	valid-aft-nloglik:9.58304
# [7]	train-aft-nloglik:8.73124	valid-aft-nloglik:9.19312
# [8]	train-aft-nloglik:8.36476	valid-aft-nloglik:8.85334
# [9]	train-aft-nloglik:8.03322	valid-aft-nloglik:8.54856
# [10]	train-aft-nloglik:7.73358	valid-aft-nloglik:8.28207
# [11]	train-aft-nloglik:7.46279	valid-aft-nloglik:8.03835
# [12]	train-aft-nloglik:7.21896	valid-aft-nloglik:7.80253
# [13]	train-aft-nloglik:6.99871	valid-aft-nloglik:7.58763
# [14]	train-aft-nloglik:6.79919	valid-aft-nloglik:7.40082
# [15]	train-aft-nloglik:6.61881	valid-aft-nloglik:7.22960
# [16]	train-aft-nloglik:6.45582	valid-aft-nloglik:7.07631
# [17]	train-aft-nloglik:6.30830	valid-aft-nloglik:6.93730
# [18]	train-aft-nloglik:6.17425	valid-aft-nloglik:6.81322
# [19]	train-aft-nloglik:6.05331	valid-aft-nloglik:6.69519
# [20]	train-aft-nloglik:5.94418	valid-aft-nloglik:6.59327
# [21]	train-aft-nloglik:5.84540	valid-aft-nloglik:6.49758
# [22]	train-aft-nloglik:5.75603	valid-aft-nloglik:6.41070
# [23]	train-aft-nloglik:5.67275	valid-aft-nloglik:6.35214
# [24]	train-aft-nloglik:5.59829	valid-aft-nloglik:6.30236
# [25]	train-aft-nloglik:5.52955	valid-aft-nloglik:6.25920
# [26]	train-aft-nloglik:5.46734	valid-aft-nloglik:6.20537
# [27]	train-aft-nloglik:5.41222	valid-aft-nloglik:6.16955
# [28]	train-aft-nloglik:5.36110	valid-aft-nloglik:6.12652
# [29]	train-aft-nloglik:5.31523	valid-aft-nloglik:6.08954
# [30]	train-aft-nloglik:5.27297	valid-aft-nloglik:6.05825
# [31]	train-aft-nloglik:5.23435	valid-aft-nloglik:6.03069
# [32]	train-aft-nloglik:5.19936	valid-aft-nloglik:6.00638
# [33]	train-aft-nloglik:5.16756	valid-aft-nloglik:5.98612
# [34]	train-aft-nloglik:5.13878	valid-aft-nloglik:5.96647
# [35]	train-aft-nloglik:5.11296	valid-aft-nloglik:5.94661
# [36]	train-aft-nloglik:5.08938	valid-aft-nloglik:5.92834
# [37]	train-aft-nloglik:5.06812	valid-aft-nloglik:5.91156
# [38]	train-aft-nloglik:5.04814	valid-aft-nloglik:5.89851
# [39]	train-aft-nloglik:5.02963	valid-aft-nloglik:5.88664
# [40]	train-aft-nloglik:5.01325	valid-aft-nloglik:5.87592
# [41]	train-aft-nloglik:4.99843	valid-aft-nloglik:5.86651
# [42]	train-aft-nloglik:4.98503	valid-aft-nloglik:5.85806
# [43]	train-aft-nloglik:4.97199	valid-aft-nloglik:5.85106
# [44]	train-aft-nloglik:4.95963	valid-aft-nloglik:5.84799
# [45]	train-aft-nloglik:4.94830	valid-aft-nloglik:5.84528
# [46]	train-aft-nloglik:4.93829	valid-aft-nloglik:5.84395
# [47]	train-aft-nloglik:4.92940	valid-aft-nloglik:5.84188
# [48]	train-aft-nloglik:4.92142	valid-aft-nloglik:5.83925
# [49]	train-aft-nloglik:4.91373	valid-aft-nloglik:5.83961
# [50]	train-aft-nloglik:4.90665	valid-aft-nloglik:5.83829
# [51]	train-aft-nloglik:4.90075	valid-aft-nloglik:5.83789
# [52]	train-aft-nloglik:4.89438	valid-aft-nloglik:5.83038
# [53]	train-aft-nloglik:4.88870	valid-aft-nloglik:5.82352
# [54]	train-aft-nloglik:4.88440	valid-aft-nloglik:5.81833
# [55]	train-aft-nloglik:4.87947	valid-aft-nloglik:5.81780
# [56]	train-aft-nloglik:4.87542	valid-aft-nloglik:5.81884
# [57]	train-aft-nloglik:4.87134	valid-aft-nloglik:5.81128
# [58]	train-aft-nloglik:4.86765	valid-aft-nloglik:5.80684
# [59]	train-aft-nloglik:4.86514	valid-aft-nloglik:5.80112
# [60]	train-aft-nloglik:4.86273	valid-aft-nloglik:5.79852
# [61]	train-aft-nloglik:4.86064	valid-aft-nloglik:5.79578
# [62]	train-aft-nloglik:4.85792	valid-aft-nloglik:5.79085
# [63]	train-aft-nloglik:4.85577	valid-aft-nloglik:5.78930
# [64]	train-aft-nloglik:4.85325	valid-aft-nloglik:5.78934
# [65]	train-aft-nloglik:4.85177	valid-aft-nloglik:5.78793
# [66]	train-aft-nloglik:4.84961	valid-aft-nloglik:5.78820
# [67]	train-aft-nloglik:4.84828	valid-aft-nloglik:5.78608
# [68]	train-aft-nloglik:4.84712	valid-aft-nloglik:5.78273
# [69]	train-aft-nloglik:4.84564	valid-aft-nloglik:5.78515
# [70]	train-aft-nloglik:4.84431	valid-aft-nloglik:5.78781
# [71]	train-aft-nloglik:4.84186	valid-aft-nloglik:5.78857
# [72]	train-aft-nloglik:4.84038	valid-aft-nloglik:5.78949
# [73]	train-aft-nloglik:4.83958	valid-aft-nloglik:5.78975
# [74]	train-aft-nloglik:4.83786	valid-aft-nloglik:5.79254
# [75]	train-aft-nloglik:4.83592	valid-aft-nloglik:5.79185
# [76]	train-aft-nloglik:4.83500	valid-aft-nloglik:5.79444
# [77]	train-aft-nloglik:4.83348	valid-aft-nloglik:5.79791
# [78]	train-aft-nloglik:4.83271	valid-aft-nloglik:5.79945
# [79]	train-aft-nloglik:4.83199	valid-aft-nloglik:5.80165
# [80]	train-aft-nloglik:4.83137	valid-aft-nloglik:5.80249
# [81]	train-aft-nloglik:4.83006	valid-aft-nloglik:5.80587
# [82]	train-aft-nloglik:4.82854	valid-aft-nloglik:5.80801
# [83]	train-aft-nloglik:4.82734	valid-aft-nloglik:5.80833
# [84]	train-aft-nloglik:4.82593	valid-aft-nloglik:5.80776
# [85]	train-aft-nloglik:4.82423	valid-aft-nloglik:5.80909
# [86]	train-aft-nloglik:4.82268	valid-aft-nloglik:5.80936
# [87]	train-aft-nloglik:4.82142	valid-aft-nloglik:5.81187
# [88]	train-aft-nloglik:4.82014	valid-aft-nloglik:5.81106
# [89]	train-aft-nloglik:4.81868	valid-aft-nloglik:5.81050
# [90]	train-aft-nloglik:4.81822	valid-aft-nloglik:5.81122
# [91]	train-aft-nloglik:4.81721	valid-aft-nloglik:5.81022
# [92]	train-aft-nloglik:4.81688	valid-aft-nloglik:5.81114
# [93]	train-aft-nloglik:4.81565	valid-aft-nloglik:5.81414
# [94]	train-aft-nloglik:4.81544	valid-aft-nloglik:5.81493
# [95]	train-aft-nloglik:4.81433	valid-aft-nloglik:5.81727
# [96]	train-aft-nloglik:4.81360	valid-aft-nloglik:5.81969
# [97]	train-aft-nloglik:4.81271	valid-aft-nloglik:5.81940
# [98]	train-aft-nloglik:4.81235	valid-aft-nloglik:5.82025
# [99]	train-aft-nloglik:4.81202	valid-aft-nloglik:5.82125
# [100]	train-aft-nloglik:4.81119	valid-aft-nloglik:5.82223
# [101]	train-aft-nloglik:4.81039	valid-aft-nloglik:5.82428
# [102]	train-aft-nloglik:4.81010	valid-aft-nloglik:5.82554
# [103]	train-aft-nloglik:4.80973	valid-aft-nloglik:5.82571
# [104]	train-aft-nloglik:4.80902	valid-aft-nloglik:5.82779
# [105]	train-aft-nloglik:4.80842	valid-aft-nloglik:5.82826
# [106]	train-aft-nloglik:4.80762	valid-aft-nloglik:5.82854
# [107]	train-aft-nloglik:4.80680	valid-aft-nloglik:5.82876
# [108]	train-aft-nloglik:4.80655	valid-aft-nloglik:5.82952
# [109]	train-aft-nloglik:4.80648	valid-aft-nloglik:5.82880
# [110]	train-aft-nloglik:4.80641	valid-aft-nloglik:5.82812
# [111]	train-aft-nloglik:4.80610	valid-aft-nloglik:5.82927
# [112]	train-aft-nloglik:4.80536	valid-aft-nloglik:5.83406
# [113]	train-aft-nloglik:4.80523	valid-aft-nloglik:5.83346
# [114]	train-aft-nloglik:4.80488	valid-aft-nloglik:5.83401
# [115]	train-aft-nloglik:4.80417	valid-aft-nloglik:5.83623
# [116]	train-aft-nloglik:4.80404	valid-aft-nloglik:5.83601
# [117]	train-aft-nloglik:4.80338	valid-aft-nloglik:5.83630
# [118]	train-aft-nloglik:4.80308	valid-aft-nloglik:5.83651

# %%
times_pred = bst.predict(dvalid, output_margin=True)
times_pred
# Out:
# array([1.2312315, 3.9123733, 3.9879122, 2.687117 , 4.0792427, 5.6348734,
#        5.745776 , 3.2588155, 5.1970477, 4.494064 , 5.23722  , 2.4928775,
#        5.31296  , 5.8244333, 3.7517586, 3.1658204, 3.8177469, 4.87757  ,
#        5.7222567, 5.2050066, 5.0286746, 4.253947 , 4.9989595, 3.474886 ,
#        3.260651 , 3.736475 , 3.7671022, 4.2022977], dtype=float32)

# %%
times_true = []
event_true = []
for idx in valid_index:
    if y_upper_bound[idx] is np.inf or not y_upper_bound[idx]:
        event = 0
    else:
        event = 1 
    event_true.append(event)
    times = y_lower_bound[idx]
    times_true.append(times)
times_true = np.array(times_true)
event_true = np.array(event_true)

# %%
times_true.shape
# Out:
# (28,)

# %%
from lifelines.utils import concordance_index
c_index = concordance_index(times_true, times_pred, event_true)
c_index
# Out:
# 0.636604774535809
