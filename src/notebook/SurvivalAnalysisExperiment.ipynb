# %% [markdown]
# # Survival Analysis

# %%
import pandas as pd
import numpy as np
from lifelines import KaplanMeierFitter
from sklearn.model_selection import train_test_split
# Out:
# /home/rizkiduwinanto/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# #### Kaplan-Meier

# %%
df = pd.read_csv('../../data/support2.csv')

# %% [markdown]
# ### Experiment with [Support2](https://archive.ics.uci.edu/dataset/880/support2)

# %%
df.head(10)
# Out:
#          age  death     sex  hospdead  slos  d.time            dzgroup  \
# 1   62.84998      0    male         0     5    2029        Lung Cancer
# 2   60.33899      1  female         1     4       4          Cirrhosis
# 3   52.74698      1  female         0    17      47          Cirrhosis
# 4   42.38498      1  female         0     3     133        Lung Cancer
# 5   79.88495      0  female         0    16    2029  ARF/MOSF w/Sepsis
# 6   93.01599      1    male         1     4       4               Coma
# 7   62.37097      1    male         0     9     659                CHF
# 8   86.83899      1    male         0     7     142                CHF
# 9   85.65594      1    male         0    12      63        Lung Cancer
# 10  42.25897      1  female         0     8     370       Colon Cancer
#
#                dzclass  num.co   edu  ...      crea    sod        ph  glucose  \
# 1               Cancer       0  11.0  ...  1.199951  141.0  7.459961      NaN
# 2   COPD/CHF/Cirrhosis       2  12.0  ...  5.500000  132.0  7.250000      NaN
# 3   COPD/CHF/Cirrhosis       2  12.0  ...  2.000000  134.0  7.459961      NaN
# 4               Cancer       2  11.0  ...  0.799927  139.0       NaN      NaN
# 5             ARF/MOSF       1   NaN  ...  0.799927  143.0  7.509766      NaN
# 6                 Coma       1  14.0  ...  0.699951  140.0  7.659180      NaN
# 7   COPD/CHF/Cirrhosis       1  14.0  ...  1.599854  132.0  7.479492      NaN
# 8   COPD/CHF/Cirrhosis       3   NaN  ...  2.000000  139.0  7.509766      NaN
# 9               Cancer       2  12.0  ...  1.000000  143.0  7.449219      NaN
# 10              Cancer       0  11.0  ...  0.799927  139.0       NaN      NaN
#
#     bun  urine adlp  adls                sfdm2   adlsc
# 1   NaN    NaN  7.0   7.0                  NaN  7.0000
# 2   NaN    NaN  NaN   1.0     <2 mo. follow-up  1.0000
# 3   NaN    NaN  1.0   0.0     <2 mo. follow-up  0.0000
# 4   NaN    NaN  0.0   0.0  no(M2 and SIP pres)  0.0000
# 5   NaN    NaN  NaN   2.0  no(M2 and SIP pres)  2.0000
# 6   NaN    NaN  NaN   1.0     <2 mo. follow-up  1.0000
# 7   NaN    NaN  0.0   1.0  no(M2 and SIP pres)  1.0000
# 8   NaN    NaN  NaN   0.0                  NaN  0.0000
# 9   NaN    NaN  NaN   7.0                  NaN  7.0000
# 10  NaN    NaN  0.0   NaN                  NaN  0.4948
#
# [10 rows x 47 columns]

# %%
df.dtypes
# Out:
# age         float64
# death         int64
# sex          object
# hospdead      int64
# slos          int64
# d.time        int64
# dzgroup      object
# dzclass      object
# num.co        int64
# edu         float64
# income       object
# scoma       float64
# charges     float64
# totcst      float64
# totmcst     float64
# avtisst     float64
# race         object
# sps         float64
# aps         float64
# surv2m      float64
# surv6m      float64
# hday          int64
# diabetes      int64
# dementia      int64
# ca           object
# prg2m       float64
# prg6m       float64
# dnr          object
# dnrday      float64
# meanbp      float64
# wblc        float64
# hrt         float64
# resp        float64
# temp        float64
# pafi        float64
# alb         float64
# bili        float64
# crea        float64
# sod         float64
# ph          float64
# glucose     float64
# bun         float64
# urine       float64
# adlp        float64
# adls        float64
# sfdm2        object
# adlsc       float64
# dtype: object

# %%
df.describe()
# Out:
#                age        death     hospdead         slos       d.time  \
# count  9105.000000  9105.000000  9105.000000  9105.000000  9105.000000
# mean     62.650823     0.681054     0.259198    17.863042   478.449863
# std      15.593710     0.466094     0.438219    22.006440   560.383272
# min      18.041990     0.000000     0.000000     3.000000     3.000000
# 25%      52.797000     0.000000     0.000000     6.000000    26.000000
# 50%      64.856990     1.000000     0.000000    11.000000   233.000000
# 75%      73.998960     1.000000     1.000000    20.000000   761.000000
# max     101.847960     1.000000     1.000000   343.000000  2029.000000
#
#             num.co          edu        scoma       charges         totcst  \
# count  9105.000000  7471.000000  9104.000000  8.933000e+03    8217.000000
# mean      1.868644    11.747691    12.058546  5.999579e+04   30825.867768
# std       1.344409     3.447743    24.636694  1.026488e+05   45780.820986
# min       0.000000     0.000000     0.000000  1.169000e+03       0.000000
# 25%       1.000000    10.000000     0.000000  9.740000e+03    5929.566400
# 50%       2.000000    12.000000     0.000000  2.502400e+04   14452.734400
# 75%       3.000000    14.000000     9.000000  6.459800e+04   36087.937500
# max       9.000000    31.000000   100.000000  1.435423e+06  633212.000000
#
#        ...         bili         crea          sod           ph      glucose  \
# count  ...  6504.000000  9038.000000  9104.000000  6821.000000  4605.000000
# mean   ...     2.554463     1.770961   137.568541     7.415364   159.873398
# std    ...     5.318448     1.686041     6.029326     0.080563    88.391541
# min    ...     0.099991     0.099991   110.000000     6.829102     0.000000
# 25%    ...     0.500000     0.899902   134.000000     7.379883   103.000000
# 50%    ...     0.899902     1.199951   137.000000     7.419922   135.000000
# 75%    ...     1.899902     1.899902   141.000000     7.469727   188.000000
# max    ...    63.000000    21.500000   181.000000     7.769531  1092.000000
#
#                bun        urine         adlp         adls        adlsc
# count  4753.000000  4243.000000  3464.000000  6238.000000  9105.000000
# mean     32.349463  2191.546047     1.157910     1.637384     1.888272
# std      26.792288  1455.245777     1.739672     2.231358     2.003763
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%      14.000000  1165.500000     0.000000     0.000000     0.000000
# 50%      23.000000  1968.000000     0.000000     1.000000     1.000000
# 75%      42.000000  3000.000000     2.000000     3.000000     3.000000
# max     300.000000  9000.000000     7.000000     7.000000     7.073242
#
# [8 rows x 39 columns]

# %%
kmf = KaplanMeierFitter()

# %%
duration = df["d.time"]
observed = df["death"]

kmf.fit(duration, event_observed=observed)
# Out:
# <lifelines.KaplanMeierFitter:"KM_estimate", fitted with 9105 total observations, 2904 right-censored observations>

# %%
from matplotlib import pyplot as plt

kmf.survival_function_.plot()
plt.title('Survival function');

# %%
kmf.plot_survival_function()
# Out:
# <Axes: xlabel='timeline'>

# %%
kmf.median_survival_time_
# Out:
# 233.0

# %%
disease_types = df['dzclass'].unique()

for i, disease_type in enumerate(disease_types):
    ax = plt.subplot(2, 3, i + 1)

    ix = df['dzclass'] == disease_type
    kmf.fit(duration[ix], observed[ix], label=disease_type)
    kmf.plot_survival_function(ax=ax, legend=False)

    plt.title(disease_type)
    plt.xlim(0, 50)

    if i==0:
        plt.ylabel('Frac. life after $n$ days')

plt.tight_layout()

# %% [markdown]
# #### Nelson-Aalen

# %%
from lifelines import NelsonAalenFitter
naf = NelsonAalenFitter()

naf.fit(duration,event_observed=observed)
# Out:
# <lifelines.NelsonAalenFitter:"NA_estimate", fitted with 9105 total observations, 2904 right-censored observations>

# %%
naf.plot_cumulative_hazard()
# Out:
# <Axes: xlabel='timeline'>

# %% [markdown]
# #### Survival Tree

# %% [markdown]
# To-do:
#
# - Create a survival tree from scikit-survival
# - Make a pipeline for data to fit into the tree
# - Change the scikit-survival data to support time-to-event

# %% [markdown]
# ##### Pipelining Data Support 2

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

class Dataset:
    def __init__(self, data, impute_rest=True):
        self.data = data
        self.preprocess(impute_rest)
        self.label = self.create_label()

    def create_label(self):
        self.data["death"] = self.data["death"].astype('bool')
        label = self.data[["death", "d.time"]]
        record = label.to_records(index=False)
        structured_arr = np.stack(record, axis=0)

        self.data.drop(["death", "d.time"], axis=1, inplace=True)

        return structured_arr

    def preprocess(self, impute_rest):
        self.impute_values(impute_rest)
        self.drop_values()
        self.data.dropna(axis=1, inplace=True)
        self.convert_to_one_hot()

        # self.data = self.data[self.data["death"] ==1]

    def impute_values(self, impute_rest):
        VALUE = {
            "alb": 3.5,
            "pafi": 333.3,
            "bili": 1.01,
            "crea": 1.01,
            "bun": 6.51,
            "wblc": 9.0,
            "urine": 2502.0,
        }

        self.data.fillna(value=VALUE, inplace=True)

    def drop_values(self):
        TO_DROP = [
            "aps",
            "sps",
            "surv2m",
            "surv6m",
            "prg2m",
            "prg6m",
            "dnr",
            "dnrday",
            "sfdm2",
            "hospdead",
            "slos",
            "charges",
            "totcst",
            "totmcst",
        ]

        self.data.drop(TO_DROP, axis=1, inplace=True)

    def convert_to_one_hot(self):
        TO_CONVERT = [
            "sex",
            "dzgroup",
            "dzclass",
            # "race",
            "ca",
            # "adlp",
            # "edu",
            # "income"
        ]
        self.data = pd.get_dummies(self.data, columns=TO_CONVERT)
    
    def get_label(self):
        return self.label

    def get_train_test(self, test_size=0.2):
        x_train, y_train, x_test, y_test = train_test_split(self.data, self.label, test_size=test_size, random_state=42)
        return x_train, y_train, x_test, y_test

    def get_data(self):
        return self.data

# %% [markdown]
# Impute NaN Values

# %%
data = Dataset(df)
trunc_data = data.get_data()
trunc_data.head()
# Out:
#         age  num.co  hday  diabetes  dementia       wblc       pafi       alb  \
# 1  62.84998       0     1         0         0   6.000000  388.00000  1.799805
# 2  60.33899       2     3         0         0  17.097656   98.00000  3.500000
# 3  52.74698       2     4         0         0   8.500000  231.65625  3.500000
# 4  42.38498       2     1         0         0   9.099609  333.30000  3.500000
# 5  79.88495       1     3         0         0  13.500000  173.31250  3.500000
#
#        bili      crea  ...  dzgroup_Coma  dzgroup_Lung Cancer  \
# 1  0.199982  1.199951  ...         False                 True
# 2  1.010000  5.500000  ...         False                False
# 3  2.199707  2.000000  ...         False                False
# 4  1.010000  0.799927  ...         False                 True
# 5  1.010000  0.799927  ...         False                False
#
#    dzgroup_MOSF w/Malig  dzclass_ARF/MOSF  dzclass_COPD/CHF/Cirrhosis  \
# 1                 False             False                       False
# 2                 False             False                        True
# 3                 False             False                        True
# 4                 False             False                       False
# 5                 False              True                       False
#
#    dzclass_Cancer  dzclass_Coma  ca_metastatic  ca_no  ca_yes
# 1            True         False           True  False   False
# 2           False         False          False   True   False
# 3           False         False          False   True   False
# 4            True         False           True  False   False
# 5           False         False          False   True   False
#
# [5 rows x 30 columns]

# %%
trunc_data.dtypes
# Out:
# age                           float64
# num.co                          int64
# hday                            int64
# diabetes                        int64
# dementia                        int64
# wblc                          float64
# pafi                          float64
# alb                           float64
# bili                          float64
# crea                          float64
# bun                           float64
# urine                         float64
# adlsc                         float64
# sex_female                       bool
# sex_male                         bool
# dzgroup_ARF/MOSF w/Sepsis        bool
# dzgroup_CHF                      bool
# dzgroup_COPD                     bool
# dzgroup_Cirrhosis                bool
# dzgroup_Colon Cancer             bool
# dzgroup_Coma                     bool
# dzgroup_Lung Cancer              bool
# dzgroup_MOSF w/Malig             bool
# dzclass_ARF/MOSF                 bool
# dzclass_COPD/CHF/Cirrhosis       bool
# dzclass_Cancer                   bool
# dzclass_Coma                     bool
# ca_metastatic                    bool
# ca_no                            bool
# ca_yes                           bool
# dtype: object

# %%
trunc_data.replace({False: 0, True: 1}, inplace=True)
# Out:
# /tmp/ipykernel_6037/1332560911.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   trunc_data.replace({False: 0, True: 1}, inplace=True)

# %%
trunc_data.dtypes
# Out:
# age                           float64
# num.co                          int64
# hday                            int64
# diabetes                        int64
# dementia                        int64
# wblc                          float64
# pafi                          float64
# alb                           float64
# bili                          float64
# crea                          float64
# bun                           float64
# urine                         float64
# adlsc                         float64
# sex_female                      int64
# sex_male                        int64
# dzgroup_ARF/MOSF w/Sepsis       int64
# dzgroup_CHF                     int64
# dzgroup_COPD                    int64
# dzgroup_Cirrhosis               int64
# dzgroup_Colon Cancer            int64
# dzgroup_Coma                    int64
# dzgroup_Lung Cancer             int64
# dzgroup_MOSF w/Malig            int64
# dzclass_ARF/MOSF                int64
# dzclass_COPD/CHF/Cirrhosis      int64
# dzclass_Cancer                  int64
# dzclass_Coma                    int64
# ca_metastatic                   int64
# ca_no                           int64
# ca_yes                          int64
# dtype: object

# %% [markdown]
# Convert label into Status and Survival Time

# %%
data_label = data.get_label()
data_label
# Out:
# array([(False, 2029), ( True,    4), ( True,   47), ..., (False,  346),
#        ( True,    7), ( True,  198)],
#       dtype=(numpy.record, [('death', '?'), ('d.time', '<i8')]))

# %% [markdown]
# Use Survival Tree

# %%
from sksurv.tree import SurvivalTree

# %%
X_train, X_test, y_train, y_test = data.get_train_test()
len(X_train), len(y_train), len(X_test), len(y_test)
# Out:
# (7284, 7284, 1821, 1821)

# %%
survtree = SurvivalTree(criterion="mixed", max_depth=5, random_state=42)

# %%
survtree.fit(X_train, y_train)
# Out:
# SurvivalTree(criterion='mixed', max_depth=5, random_state=42)

# %%
survtree.score(X_test, y_test)
# Out:
# np.float64(0.6445033510683764)

# %%
X_test_sorted = X_test.sort_values(by=["age"])
X_test_sel = pd.concat((X_test_sorted.head(3), X_test_sorted.tail(3)))

X_test_sel
# Out:
#             age  num.co  hday  diabetes  dementia       wblc       pafi  \
# 9095   18.04199       0     4         0         0  11.599609  240.00000
# 178    18.14600       2     1         0         0   2.000000  314.25000
# 7539   18.77599       0     1         0         0  17.097656   46.66406
# 5946   97.51099       2     1         0         0  11.398438  204.75000
# 2390  100.13098       3     1         0         0   6.000000  333.30000
# 7609  101.84796       4     1         0         0   8.000000  333.30000
#
#            alb      bili       crea  ...  dzgroup_Coma  dzgroup_Lung Cancer  \
# 9095  3.500000  1.010000   0.899902  ...             0                    0
# 178   1.899902  0.299988  10.699219  ...             0                    0
# 7539  3.399902  1.099854   1.699951  ...             0                    0
# 5946  4.000000  0.899902   1.099854  ...             1                    0
# 2390  3.699707  1.010000   1.099854  ...             0                    0
# 7609  3.699707  1.500000   1.699951  ...             0                    0
#
#       dzgroup_MOSF w/Malig  dzclass_ARF/MOSF  dzclass_COPD/CHF/Cirrhosis  \
# 9095                     1                 1                           0
# 178                      0                 1                           0
# 7539                     0                 1                           0
# 5946                     0                 0                           0
# 2390                     0                 0                           1
# 7609                     0                 0                           1
#
#       dzclass_Cancer  dzclass_Coma  ca_metastatic  ca_no  ca_yes
# 9095               0             0              0      0       1
# 178                0             0              0      1       0
# 7539               0             0              0      1       0
# 5946               0             1              0      1       0
# 2390               0             0              0      0       1
# 7609               0             0              0      1       0
#
# [6 rows x 30 columns]

# %%
survtree.predict(X_test_sel)
# Out:
# array([2503.53224845,  319.02846732,  319.02846732, 1781.57608455,
#        1264.161146  , 1003.60908218])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

surv = survtree.predict_survival_function(X_test_sel, return_array=True)

for i, s in enumerate(surv):
    plt.step(survtree.unique_times_, s, where="post", label=str(i))
plt.ylabel("Survival probability")
plt.xlabel("Time in days")
plt.legend()
plt.grid(True)

# %%
from visualize import plot_tree

plot_tree(survtree, max_depth=2, feature_names=X_train.columns, fontsize=8)
# Out:
# [Text(248.0, 323.4, 'ca_no <= 0.5\nlogrank = inf\nsamples = 7284\nvalue = np.bytes_()'),
#  Text(124.0, 230.99999999999997, 'adlsc <= 2.638\nlogrank = inf\nsamples = 2493\nvalue = np.bytes_()'),
#  Text(62.0, 138.6, 'dzgroup_MOSF w/Malig <= 0.5\nlogrank = inf\nsamples = 1745\nvalue = np.bytes_()'),
#  Text(31.0, 46.19999999999999, '\n  (...)  \n'),
#  Text(93.0, 46.19999999999999, '\n  (...)  \n'),
#  Text(186.0, 138.6, 'dzgroup_MOSF w/Malig <= 0.5\nlogrank = inf\nsamples = 748\nvalue = np.bytes_()'),
#  Text(155.0, 46.19999999999999, '\n  (...)  \n'),
#  Text(217.0, 46.19999999999999, '\n  (...)  \n'),
#  Text(372.0, 230.99999999999997, 'dzclass_Coma <= 0.5\nlogrank = inf\nsamples = 4791\nvalue = np.bytes_()'),
#  Text(310.0, 138.6, 'adlsc <= 1.862\nlogrank = inf\nsamples = 4391\nvalue = np.bytes_()'),
#  Text(279.0, 46.19999999999999, '\n  (...)  \n'),
#  Text(341.0, 46.19999999999999, '\n  (...)  \n'),
#  Text(434.0, 138.6, 'adlsc <= 0.5\nlogrank = inf\nsamples = 400\nvalue = np.bytes_()'),
#  Text(403.0, 46.19999999999999, '\n  (...)  \n'),
#  Text(465.0, 46.19999999999999, '\n  (...)  \n')]

# %%
plot_tree(survtree, feature_names=X_train.columns, fontsize=3, class_names=["alive", "dead"])
plt.savefig("survival_tree.pdf")

# %% [markdown]
# Accelerated Failure Time Model

# %%
from sksurv.linear_model import IPCRidge

ipcr = IPCRidge(alpha=1.)
ipcr.fit(X_train, y_train)
# Out:
# IPCRidge()

# %%
ipcr.score(X_test, y_test)
# Out:
# np.float64(0.6333974634731445)

# %%
x_test_sel = X_test.sort_values(by=["age"]).tail(3)

ipcr.predict(x_test_sel)
# Out:
# array([ 11.74224114, 194.78441742, 144.64217079])

# %% [markdown]
# To Do:
# - Explore Cython
# - Explore Log Rank and MSE and how to merge it
# - Explore AFT
# - Output must be time to event
