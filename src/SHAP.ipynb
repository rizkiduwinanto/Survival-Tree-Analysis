# %%
import matplotlib.pylab as pl
import numpy as np
import xgboost
from sklearn.model_selection import train_test_split

import shap
# Out:
# /home/rizkiduwinanto/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
X, y = shap.datasets.nhanesi()

# %%
X
# Out:
#        sex_isFemale  age  physical_activity  serum_albumin  \
# 20751         False   51                  3            NaN
# 20753         False   41                  2            NaN
# 20754          True   31                  2            NaN
# 20755         False   48                  2            NaN
# 20756          True   29                  3            NaN
# ...             ...  ...                ...            ...
# 25043          True   63                  2            NaN
# 25046          True   56                  2            NaN
# 25049          True   47                  2            NaN
# 25057          True   61                  8            NaN
# 25061         False   29                  3            NaN
#
#        alkaline_phosphatase  alkaline_phosphatase_isUnacceptable  \
# 20751                  85.0                                False
# 20753                  68.0                                False
# 20754                  61.0                                False
# 20755                  58.0                                False
# 20756                  37.0                                False
# ...                     ...                                  ...
# 25043                  86.0                                False
# 25046                  65.0                                False
# 25049                  46.0                                False
# 25057                  75.0                                False
# 25061                  84.0                                False
#
#        alkaline_phosphatase_isTestnotdone  SGOT  SGOT_isUnacceptable  \
# 20751                               False   NaN                 True
# 20753                               False  2.27                False
# 20754                               False  1.86                False
# 20755                               False   NaN                 True
# 20756                               False  1.69                False
# ...                                   ...   ...                  ...
# 25043                               False  2.24                False
# 25046                               False  2.31                False
# 25049                               False  1.93                False
# 25057                               False  2.29                False
# 25061                               False  3.02                False
#
#        SGOT_isTestnotdone  ...  urine_hematest_isLarge  \
# 20751               False  ...                   False
# 20753               False  ...                   False
# 20754               False  ...                   False
# 20755               False  ...                   False
# 20756               False  ...                   False
# ...                   ...  ...                     ...
# 25043               False  ...                   False
# 25046               False  ...                   False
# 25049               False  ...                   False
# 25057               False  ...                   False
# 25061               False  ...                   False
#
#        urine_hematest_isBlankbutapplicable  sedimentation_rate  \
# 20751                                False                 NaN
# 20753                                False                 NaN
# 20754                                False                 NaN
# 20755                                False                 NaN
# 20756                                False                 NaN
# ...                                    ...                 ...
# 25043                                False                 NaN
# 25046                                False                 NaN
# 25049                                False                 NaN
# 25057                                False                 NaN
# 25061                                False                 NaN
#
#        sedimentation_rate_isBlankbutapplicable  uric_acid  \
# 20751                                    False        6.2
# 20753                                    False        7.7
# 20754                                    False        4.9
# 20755                                    False        8.4
# 20756                                    False        4.3
# ...                                        ...        ...
# 25043                                    False        7.2
# 25046                                    False        5.1
# 25049                                    False        3.2
# 25057                                    False        6.8
# 25061                                    False        6.1
#
#        uric_acid_isUnacceptable  uric_acid_isTestnotdone  \
# 20751                     False                    False
# 20753                     False                    False
# 20754                     False                    False
# 20755                     False                    False
# 20756                     False                    False
# ...                         ...                      ...
# 25043                     False                    False
# 25046                     False                    False
# 25049                     False                    False
# 25057                     False                    False
# 25061                     False                    False
#
#        systolic_blood_pressure  pulse_pressure        bmi
# 20751                    110.0            40.0  25.406803
# 20753                    136.0            54.0  24.588331
# 20754                    110.0            24.0  23.756502
# 20755                    126.0            36.0  28.610011
# 20756                     98.0            36.0  19.216489
# ...                        ...             ...        ...
# 25043                    150.0            65.0  35.425033
# 25046                     98.0            38.0  22.069132
# 25049                    108.0            28.0  17.915199
# 25057                    180.0            68.0  27.331622
# 25061                    152.0            60.0  33.161435
#
# [14264 rows x 79 columns]

# %%
y
# Out:
# array([-16.91666667, -17.16666667, -17.66666667, ..., -17.08333333,
#        -17.08333333, -17.08333333])

# %%
X_display, y_display = shap.datasets.nhanesi(display=True)

# %%
X_display
# Out:
#        sex_isFemale  age  physical_activity  serum_albumin  \
# 20751         False   51                  3            NaN
# 20753         False   41                  2            NaN
# 20754          True   31                  2            NaN
# 20755         False   48                  2            NaN
# 20756          True   29                  3            NaN
# ...             ...  ...                ...            ...
# 25043          True   63                  2            NaN
# 25046          True   56                  2            NaN
# 25049          True   47                  2            NaN
# 25057          True   61                  8            NaN
# 25061         False   29                  3            NaN
#
#        alkaline_phosphatase  alkaline_phosphatase_isUnacceptable  \
# 20751                  85.0                                False
# 20753                  68.0                                False
# 20754                  61.0                                False
# 20755                  58.0                                False
# 20756                  37.0                                False
# ...                     ...                                  ...
# 25043                  86.0                                False
# 25046                  65.0                                False
# 25049                  46.0                                False
# 25057                  75.0                                False
# 25061                  84.0                                False
#
#        alkaline_phosphatase_isTestnotdone  SGOT  SGOT_isUnacceptable  \
# 20751                               False   NaN                 True
# 20753                               False  2.27                False
# 20754                               False  1.86                False
# 20755                               False   NaN                 True
# 20756                               False  1.69                False
# ...                                   ...   ...                  ...
# 25043                               False  2.24                False
# 25046                               False  2.31                False
# 25049                               False  1.93                False
# 25057                               False  2.29                False
# 25061                               False  3.02                False
#
#        SGOT_isTestnotdone  ...  urine_hematest_isLarge  \
# 20751               False  ...                   False
# 20753               False  ...                   False
# 20754               False  ...                   False
# 20755               False  ...                   False
# 20756               False  ...                   False
# ...                   ...  ...                     ...
# 25043               False  ...                   False
# 25046               False  ...                   False
# 25049               False  ...                   False
# 25057               False  ...                   False
# 25061               False  ...                   False
#
#        urine_hematest_isBlankbutapplicable  sedimentation_rate  \
# 20751                                False                 NaN
# 20753                                False                 NaN
# 20754                                False                 NaN
# 20755                                False                 NaN
# 20756                                False                 NaN
# ...                                    ...                 ...
# 25043                                False                 NaN
# 25046                                False                 NaN
# 25049                                False                 NaN
# 25057                                False                 NaN
# 25061                                False                 NaN
#
#        sedimentation_rate_isBlankbutapplicable  uric_acid  \
# 20751                                    False        6.2
# 20753                                    False        7.7
# 20754                                    False        4.9
# 20755                                    False        8.4
# 20756                                    False        4.3
# ...                                        ...        ...
# 25043                                    False        7.2
# 25046                                    False        5.1
# 25049                                    False        3.2
# 25057                                    False        6.8
# 25061                                    False        6.1
#
#        uric_acid_isUnacceptable  uric_acid_isTestnotdone  \
# 20751                     False                    False
# 20753                     False                    False
# 20754                     False                    False
# 20755                     False                    False
# 20756                     False                    False
# ...                         ...                      ...
# 25043                     False                    False
# 25046                     False                    False
# 25049                     False                    False
# 25057                     False                    False
# 25061                     False                    False
#
#        systolic_blood_pressure  pulse_pressure        bmi
# 20751                    110.0            40.0  25.406803
# 20753                    136.0            54.0  24.588331
# 20754                    110.0            24.0  23.756502
# 20755                    126.0            36.0  28.610011
# 20756                     98.0            36.0  19.216489
# ...                        ...             ...        ...
# 25043                    150.0            65.0  35.425033
# 25046                     98.0            38.0  22.069132
# 25049                    108.0            28.0  17.915199
# 25057                    180.0            68.0  27.331622
# 25061                    152.0            60.0  33.161435
#
# [14264 rows x 79 columns]

# %%
y_display
# Out:
# array([-16.91666667, -17.16666667, -17.66666667, ..., -17.08333333,
#        -17.08333333, -17.08333333])

# %%
X_display.describe()
# Out:
#                 age  physical_activity  serum_albumin  alkaline_phosphatase  \
# count  14264.000000       14264.000000   10671.000000           6321.000000
# mean      48.905707           2.957656       4.362309             60.169245
# std       15.574155           0.999980       0.328457             25.892123
# min       25.000000           1.000000       2.700000              4.800000
# 25%       35.000000           2.000000       4.200000             45.000000
# 50%       48.000000           3.000000       4.400000             57.000000
# 75%       65.000000           3.000000       4.600000             70.000000
# max       75.000000           8.000000       5.700000            580.000000
#
#               SGOT          BUN      calcium   creatinine    potassium  \
# count  6275.000000  2926.000000  6218.000000  2582.000000  2984.000000
# mean      2.428056    14.807724     9.670553     1.008172     4.069135
# std       1.492351     4.455391     0.478994     0.284194     0.344551
# min       0.270000     0.800000     0.200000     0.400000     2.700000
# 25%       1.800000    12.000000     9.400000     0.900000     3.800000
# 50%       2.200000    14.000000     9.700000     1.000000     4.100000
# 75%       2.600000    17.000000    10.000000     1.100000     4.300000
# max      31.000000    49.000000    12.500000     9.000000     5.400000
#
#             sodium  ...  eosinophils    basophils  band_neutrophils  \
# count  2995.000000  ...  5818.000000  5818.000000       5818.000000
# mean    142.369616  ...     2.014610     0.131317          0.252320
# std       3.113626  ...     2.084008     0.393272          1.093025
# min     121.000000  ...     0.000000     0.000000          0.000000
# 25%     141.000000  ...     0.000000     0.000000          0.000000
# 50%     143.000000  ...     1.000000     0.000000          0.000000
# 75%     144.000000  ...     3.000000     0.000000          0.000000
# max     157.000000  ...    17.000000     3.000000         22.000000
#
#         cholesterol      urine_pH  sedimentation_rate    uric_acid  \
# count  13832.000000  13572.000000        10182.000000  6606.000000
# mean     220.775087      5.628721           16.125516     5.524342
# std       48.390905      0.773717           11.424670     1.467420
# min       53.000000      5.000000            1.000000     0.700000
# 25%      187.000000      5.000000            7.000000     4.500000
# 50%      217.000000      5.000000           14.000000     5.400000
# 75%      249.000000      6.000000           22.000000     6.500000
# max      793.000000      9.000000           72.000000    12.500000
#
#        systolic_blood_pressure  pulse_pressure           bmi
# count             14264.000000    14260.000000  14264.000000
# mean                134.133553       50.639902     25.620677
# std                  24.383336       18.019190      5.104078
# min                  80.000000       10.000000     12.418360
# 25%                 118.000000       38.000000     22.057446
# 50%                 130.000000       48.000000     24.925918
# 75%                 148.000000       60.000000     28.243033
# max                 270.000000      170.000000     72.314050
#
# [8 rows x 29 columns]

# %%
X.columns[X.isna().any()]
# Out:
# Index(['serum_albumin', 'alkaline_phosphatase', 'SGOT', 'BUN', 'calcium',
#        'creatinine', 'potassium', 'sodium', 'total_bilirubin', 'serum_protein',
#        'red_blood_cells', 'white_blood_cells', 'hemoglobin', 'hematocrit',
#        'segmented_neutrophils', 'lymphocytes', 'monocytes', 'eosinophils',
#        'basophils', 'band_neutrophils', 'cholesterol', 'urine_pH',
#        'sedimentation_rate', 'uric_acid', 'pulse_pressure'],
#       dtype='object')

# %%
X.columns[X.dtypes == 'object']
# Out:
# Index([], dtype='object')
