# %%
import matplotlib.pylab as pl
import numpy as np
import xgboost
from sklearn.model_selection import train_test_split

import shap
# Out:
# /home/rizkiduwinanto/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
X, y = shap.datasets.nhanesi()

# %%
X
# Out:
#        sex_isFemale  age  physical_activity  serum_albumin  \
# 20751         False   51                  3            NaN
# 20753         False   41                  2            NaN
# 20754          True   31                  2            NaN
# 20755         False   48                  2            NaN
# 20756          True   29                  3            NaN
# ...             ...  ...                ...            ...
# 25043          True   63                  2            NaN
# 25046          True   56                  2            NaN
# 25049          True   47                  2            NaN
# 25057          True   61                  8            NaN
# 25061         False   29                  3            NaN
#
#        alkaline_phosphatase  alkaline_phosphatase_isUnacceptable  \
# 20751                  85.0                                False
# 20753                  68.0                                False
# 20754                  61.0                                False
# 20755                  58.0                                False
# 20756                  37.0                                False
# ...                     ...                                  ...
# 25043                  86.0                                False
# 25046                  65.0                                False
# 25049                  46.0                                False
# 25057                  75.0                                False
# 25061                  84.0                                False
#
#        alkaline_phosphatase_isTestnotdone  SGOT  SGOT_isUnacceptable  \
# 20751                               False   NaN                 True
# 20753                               False  2.27                False
# 20754                               False  1.86                False
# 20755                               False   NaN                 True
# 20756                               False  1.69                False
# ...                                   ...   ...                  ...
# 25043                               False  2.24                False
# 25046                               False  2.31                False
# 25049                               False  1.93                False
# 25057                               False  2.29                False
# 25061                               False  3.02                False
#
#        SGOT_isTestnotdone  ...  urine_hematest_isLarge  \
# 20751               False  ...                   False
# 20753               False  ...                   False
# 20754               False  ...                   False
# 20755               False  ...                   False
# 20756               False  ...                   False
# ...                   ...  ...                     ...
# 25043               False  ...                   False
# 25046               False  ...                   False
# 25049               False  ...                   False
# 25057               False  ...                   False
# 25061               False  ...                   False
#
#        urine_hematest_isBlankbutapplicable  sedimentation_rate  \
# 20751                                False                 NaN
# 20753                                False                 NaN
# 20754                                False                 NaN
# 20755                                False                 NaN
# 20756                                False                 NaN
# ...                                    ...                 ...
# 25043                                False                 NaN
# 25046                                False                 NaN
# 25049                                False                 NaN
# 25057                                False                 NaN
# 25061                                False                 NaN
#
#        sedimentation_rate_isBlankbutapplicable  uric_acid  \
# 20751                                    False        6.2
# 20753                                    False        7.7
# 20754                                    False        4.9
# 20755                                    False        8.4
# 20756                                    False        4.3
# ...                                        ...        ...
# 25043                                    False        7.2
# 25046                                    False        5.1
# 25049                                    False        3.2
# 25057                                    False        6.8
# 25061                                    False        6.1
#
#        uric_acid_isUnacceptable  uric_acid_isTestnotdone  \
# 20751                     False                    False
# 20753                     False                    False
# 20754                     False                    False
# 20755                     False                    False
# 20756                     False                    False
# ...                         ...                      ...
# 25043                     False                    False
# 25046                     False                    False
# 25049                     False                    False
# 25057                     False                    False
# 25061                     False                    False
#
#        systolic_blood_pressure  pulse_pressure        bmi
# 20751                    110.0            40.0  25.406803
# 20753                    136.0            54.0  24.588331
# 20754                    110.0            24.0  23.756502
# 20755                    126.0            36.0  28.610011
# 20756                     98.0            36.0  19.216489
# ...                        ...             ...        ...
# 25043                    150.0            65.0  35.425033
# 25046                     98.0            38.0  22.069132
# 25049                    108.0            28.0  17.915199
# 25057                    180.0            68.0  27.331622
# 25061                    152.0            60.0  33.161435
#
# [14264 rows x 79 columns]

# %%
y
# Out:
# array([-16.91666667, -17.16666667, -17.66666667, ..., -17.08333333,
#        -17.08333333, -17.08333333])

# %%
X_display, y_display = shap.datasets.nhanesi(display=True)

# %%
X_display
# Out:
#        sex_isFemale  age  physical_activity  serum_albumin  \
# 20751         False   51                  3            NaN
# 20753         False   41                  2            NaN
# 20754          True   31                  2            NaN
# 20755         False   48                  2            NaN
# 20756          True   29                  3            NaN
# ...             ...  ...                ...            ...
# 25043          True   63                  2            NaN
# 25046          True   56                  2            NaN
# 25049          True   47                  2            NaN
# 25057          True   61                  8            NaN
# 25061         False   29                  3            NaN
#
#        alkaline_phosphatase  alkaline_phosphatase_isUnacceptable  \
# 20751                  85.0                                False
# 20753                  68.0                                False
# 20754                  61.0                                False
# 20755                  58.0                                False
# 20756                  37.0                                False
# ...                     ...                                  ...
# 25043                  86.0                                False
# 25046                  65.0                                False
# 25049                  46.0                                False
# 25057                  75.0                                False
# 25061                  84.0                                False
#
#        alkaline_phosphatase_isTestnotdone  SGOT  SGOT_isUnacceptable  \
# 20751                               False   NaN                 True
# 20753                               False  2.27                False
# 20754                               False  1.86                False
# 20755                               False   NaN                 True
# 20756                               False  1.69                False
# ...                                   ...   ...                  ...
# 25043                               False  2.24                False
# 25046                               False  2.31                False
# 25049                               False  1.93                False
# 25057                               False  2.29                False
# 25061                               False  3.02                False
#
#        SGOT_isTestnotdone  ...  urine_hematest_isLarge  \
# 20751               False  ...                   False
# 20753               False  ...                   False
# 20754               False  ...                   False
# 20755               False  ...                   False
# 20756               False  ...                   False
# ...                   ...  ...                     ...
# 25043               False  ...                   False
# 25046               False  ...                   False
# 25049               False  ...                   False
# 25057               False  ...                   False
# 25061               False  ...                   False
#
#        urine_hematest_isBlankbutapplicable  sedimentation_rate  \
# 20751                                False                 NaN
# 20753                                False                 NaN
# 20754                                False                 NaN
# 20755                                False                 NaN
# 20756                                False                 NaN
# ...                                    ...                 ...
# 25043                                False                 NaN
# 25046                                False                 NaN
# 25049                                False                 NaN
# 25057                                False                 NaN
# 25061                                False                 NaN
#
#        sedimentation_rate_isBlankbutapplicable  uric_acid  \
# 20751                                    False        6.2
# 20753                                    False        7.7
# 20754                                    False        4.9
# 20755                                    False        8.4
# 20756                                    False        4.3
# ...                                        ...        ...
# 25043                                    False        7.2
# 25046                                    False        5.1
# 25049                                    False        3.2
# 25057                                    False        6.8
# 25061                                    False        6.1
#
#        uric_acid_isUnacceptable  uric_acid_isTestnotdone  \
# 20751                     False                    False
# 20753                     False                    False
# 20754                     False                    False
# 20755                     False                    False
# 20756                     False                    False
# ...                         ...                      ...
# 25043                     False                    False
# 25046                     False                    False
# 25049                     False                    False
# 25057                     False                    False
# 25061                     False                    False
#
#        systolic_blood_pressure  pulse_pressure        bmi
# 20751                    110.0            40.0  25.406803
# 20753                    136.0            54.0  24.588331
# 20754                    110.0            24.0  23.756502
# 20755                    126.0            36.0  28.610011
# 20756                     98.0            36.0  19.216489
# ...                        ...             ...        ...
# 25043                    150.0            65.0  35.425033
# 25046                     98.0            38.0  22.069132
# 25049                    108.0            28.0  17.915199
# 25057                    180.0            68.0  27.331622
# 25061                    152.0            60.0  33.161435
#
# [14264 rows x 79 columns]

# %%
y_display
# Out:
# array([-16.91666667, -17.16666667, -17.66666667, ..., -17.08333333,
#        -17.08333333, -17.08333333])

# %%
X_display.fillna(X_display.median())
# Out:
#        sex_isFemale  age  physical_activity  serum_albumin  \
# 20751         False   51                  3            4.4
# 20753         False   41                  2            4.4
# 20754          True   31                  2            4.4
# 20755         False   48                  2            4.4
# 20756          True   29                  3            4.4
# ...             ...  ...                ...            ...
# 25043          True   63                  2            4.4
# 25046          True   56                  2            4.4
# 25049          True   47                  2            4.4
# 25057          True   61                  8            4.4
# 25061         False   29                  3            4.4
#
#        alkaline_phosphatase  alkaline_phosphatase_isUnacceptable  \
# 20751                  85.0                                False
# 20753                  68.0                                False
# 20754                  61.0                                False
# 20755                  58.0                                False
# 20756                  37.0                                False
# ...                     ...                                  ...
# 25043                  86.0                                False
# 25046                  65.0                                False
# 25049                  46.0                                False
# 25057                  75.0                                False
# 25061                  84.0                                False
#
#        alkaline_phosphatase_isTestnotdone  SGOT  SGOT_isUnacceptable  \
# 20751                               False  2.20                 True
# 20753                               False  2.27                False
# 20754                               False  1.86                False
# 20755                               False  2.20                 True
# 20756                               False  1.69                False
# ...                                   ...   ...                  ...
# 25043                               False  2.24                False
# 25046                               False  2.31                False
# 25049                               False  1.93                False
# 25057                               False  2.29                False
# 25061                               False  3.02                False
#
#        SGOT_isTestnotdone  ...  urine_hematest_isLarge  \
# 20751               False  ...                   False
# 20753               False  ...                   False
# 20754               False  ...                   False
# 20755               False  ...                   False
# 20756               False  ...                   False
# ...                   ...  ...                     ...
# 25043               False  ...                   False
# 25046               False  ...                   False
# 25049               False  ...                   False
# 25057               False  ...                   False
# 25061               False  ...                   False
#
#        urine_hematest_isBlankbutapplicable  sedimentation_rate  \
# 20751                                False                14.0
# 20753                                False                14.0
# 20754                                False                14.0
# 20755                                False                14.0
# 20756                                False                14.0
# ...                                    ...                 ...
# 25043                                False                14.0
# 25046                                False                14.0
# 25049                                False                14.0
# 25057                                False                14.0
# 25061                                False                14.0
#
#        sedimentation_rate_isBlankbutapplicable  uric_acid  \
# 20751                                    False        6.2
# 20753                                    False        7.7
# 20754                                    False        4.9
# 20755                                    False        8.4
# 20756                                    False        4.3
# ...                                        ...        ...
# 25043                                    False        7.2
# 25046                                    False        5.1
# 25049                                    False        3.2
# 25057                                    False        6.8
# 25061                                    False        6.1
#
#        uric_acid_isUnacceptable  uric_acid_isTestnotdone  \
# 20751                     False                    False
# 20753                     False                    False
# 20754                     False                    False
# 20755                     False                    False
# 20756                     False                    False
# ...                         ...                      ...
# 25043                     False                    False
# 25046                     False                    False
# 25049                     False                    False
# 25057                     False                    False
# 25061                     False                    False
#
#        systolic_blood_pressure  pulse_pressure        bmi
# 20751                    110.0            40.0  25.406803
# 20753                    136.0            54.0  24.588331
# 20754                    110.0            24.0  23.756502
# 20755                    126.0            36.0  28.610011
# 20756                     98.0            36.0  19.216489
# ...                        ...             ...        ...
# 25043                    150.0            65.0  35.425033
# 25046                     98.0            38.0  22.069132
# 25049                    108.0            28.0  17.915199
# 25057                    180.0            68.0  27.331622
# 25061                    152.0            60.0  33.161435
#
# [14264 rows x 79 columns]

# %%
from dataset import NHANESDataset

dataset = NHANESDataset()
data = dataset.get_data()
# Out:
# /mnt/c/Users/rizki/Master Files/ThesisUMCG/Survival-Tree-Analysis/src/dataset.py:210: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   self.data.replace({False: 0, True: 1}, inplace=True)

# %%
data
# Out:
# array([[  0.        ,  51.        ,   3.        , ..., 110.        ,
#          40.        ,  25.40680287],
#        [  0.        ,  41.        ,   2.        , ..., 136.        ,
#          54.        ,  24.58833109],
#        [  1.        ,  31.        ,   2.        , ..., 110.        ,
#          24.        ,  23.75650236],
#        ...,
#        [  1.        ,  47.        ,   2.        , ..., 108.        ,
#          28.        ,  17.9151988 ],
#        [  1.        ,  61.        ,   8.        , ..., 180.        ,
#          68.        ,  27.33162171],
#        [  0.        ,  29.        ,   3.        , ..., 152.        ,
#          60.        ,  33.16143518]])
